# %% [markdown]
# Using any text embedding model, we aim to find similar phrases (to the 3 hotwords previously) to increase the diversity of the hotword dictionary, thereby increasing the overall effectiveness of our AI pipeline.

# %% [markdown]
# Google BERT is then selected since it is a powerful general-purpose language model. We then tap on the unmasking feature to generate similar words to the given hotwords, and rearrange the order to increase the vocabulary size.

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("fill-mask", model="google-bert/bert-base-uncased")

# %%
unmasker = pipeline('fill-mask', model='bert-base-uncased')

# %%
query1 = "be careful, destroy, [MASK], stranger"

outputs1 = unmasker(query1)
outputs1

# %%
query2 = "be careful, [MASK], destroy, stranger"

outputs2 = unmasker(query2)
outputs2

# %%
query3 = "[MASK], be careful, destroy, stranger"

outputs3 = unmasker(query3)
outputs3

# %%
outputs = []
outputs.extend([prediction['token_str'] for prediction in outputs1])
outputs.extend([prediction['token_str'] for prediction in outputs2])
outputs.extend([prediction['token_str'] for prediction in outputs3])

outputs
# Out:
# ['stranger',
#  'kill',
#  'destroy',
#  'protect',
#  'danger',
#  'destroy',
#  'kill',
#  'protect',
#  'fight',
#  'attack',
#  'destroy',
#  'kill',
#  'please',
#  'protect',
#  'but']

# %%
PATH = 'hotword_inference.csv'

# %%
import pandas as pd

results_df = pd.read_csv(PATH) 
results_df['pred_str_lowercase'] = results_df['pred_str'].str.lower()
results_df
# Out:
#       Unnamed: 0                        filename  \
# 0              0  cv-valid-dev/sample-000000.mp3
# 1              1  cv-valid-dev/sample-000001.mp3
# 2              2  cv-valid-dev/sample-000002.mp3
# 3              3  cv-valid-dev/sample-000003.mp3
# 4              4  cv-valid-dev/sample-000004.mp3
# ...          ...                             ...
# 4071        4071  cv-valid-dev/sample-004071.mp3
# 4072        4072  cv-valid-dev/sample-004072.mp3
# 4073        4073  cv-valid-dev/sample-004073.mp3
# 4074        4074  cv-valid-dev/sample-004074.mp3
# 4075        4075  cv-valid-dev/sample-004075.mp3
#
#                                                    text  \
# 0     BE CAREFUL WITH YOUR PROGNOSTICATIONS SAID THE...
# 1     THEN WHY SHOULD THEY BE SURPRISED WHEN THEY SE...
# 2     A YOUNG ARAB ALSO LOADED DOWN WITH BAGGAGE ENT...
# 3     I THOUGHT THAT EVERYTHING I OWNED WOULD BE DES...
# 4     HE MOVED ABOUT INVISIBLE BUT EVERYONE COULD HE...
# ...                                                 ...
# 4071        BUT THEY COULD NEVER HAVE TAUGHT HIM ARABIC
# 4072  HE DECIDED TO CONCENTRATE ON MORE PRACTICAL MA...
# 4073                THAT'S WHAT I'M NOT SUPPOSED TO SAY
# 4074            JUST HANDLING THEM MADE HIM FEEL BETTER
# 4075                           THE CITY SEALER'S OFFICE
#
#                                                pred_str  \
# 0     BE CAREFUL WITH YOUR PROPMASTIGATIONS SAID THE...
# 1     THEN WHY SHOULD THEY BE SURPRISED WHEN THI SEE...
# 2     A YOUNG ARAB ALSO LOADED DOWN WITH BAGGAGE ENT...
# 3     I FELT THAT EVERYTHING I OWNED WOULD BE DESTROYED
# 4     HE MOVED ABOUT INVISIBLE BUT EVERY ONE COULD H...
# ...                                                 ...
# 4071        BUT THEY COULD NEVER HAVE TAUGHT HIM ARABIC
# 4072  HE DECIDED TO CONCENTRATE ON MORE PRACTICAL MA...
# 4073                THAT'S WHAT I'M NOT SUPPOSED TO SAY
# 4074                JUST ANDILY PO BAD HIM FEEL PICTURE
# 4075                           THE CITY SEALER'S OFFICE
#
#                                      pred_str_lowercase
# 0     be careful with your propmastigations said the...
# 1     then why should they be surprised when thi see...
# 2     a young arab also loaded down with baggage ent...
# 3     i felt that everything i owned would be destroyed
# 4     he moved about invisible but every one could h...
# ...                                                 ...
# 4071        but they could never have taught him arabic
# 4072  he decided to concentrate on more practical ma...
# 4073                that's what i'm not supposed to say
# 4074                just andily po bad him feel picture
# 4075                           the city sealer's office
#
# [4076 rows x 5 columns]

# %%
# Define hotwords
hotwords = ["be careful", "destroy", "stranger"]

# %%
# extend hotwords and cast into string type
hotwords.extend(outputs)
hotwords_list = [str(word) for word in hotwords] 
hotwords_list

# %%
# doing manual revision: "but" isnt that similar to the other phrases, hence removing
word_to_remove = 'but'

# Remove the word from the list
hotwords_list = list(filter(lambda x: x != word_to_remove, hotwords_list)) 
hotwords_list

# %%
# observed repeated words, removing repeats
hotwords_list = list(set(hotwords_list)) 
hotwords_list
# Out:
# ['kill',
#  'attack',
#  'danger',
#  'please',
#  'be careful',
#  'protect',
#  'stranger',
#  'fight',
#  'destroy']

# %%
def contains_hotword(text):
  for hotword in hotwords_list:
    if hotword.lower() in str(text).lower():
      return 1
  return 0

# %%
# Create a new column 'contains_hotword'

results_df['similarity'] = results_df['pred_str_lowercase'].apply(lambda x: contains_hotword(x))
results_df
# Out:
#       Unnamed: 0                        filename  \
# 0              0  cv-valid-dev/sample-000000.mp3
# 1              1  cv-valid-dev/sample-000001.mp3
# 2              2  cv-valid-dev/sample-000002.mp3
# 3              3  cv-valid-dev/sample-000003.mp3
# 4              4  cv-valid-dev/sample-000004.mp3
# ...          ...                             ...
# 4071        4071  cv-valid-dev/sample-004071.mp3
# 4072        4072  cv-valid-dev/sample-004072.mp3
# 4073        4073  cv-valid-dev/sample-004073.mp3
# 4074        4074  cv-valid-dev/sample-004074.mp3
# 4075        4075  cv-valid-dev/sample-004075.mp3
#
#                                                    text  \
# 0     BE CAREFUL WITH YOUR PROGNOSTICATIONS SAID THE...
# 1     THEN WHY SHOULD THEY BE SURPRISED WHEN THEY SE...
# 2     A YOUNG ARAB ALSO LOADED DOWN WITH BAGGAGE ENT...
# 3     I THOUGHT THAT EVERYTHING I OWNED WOULD BE DES...
# 4     HE MOVED ABOUT INVISIBLE BUT EVERYONE COULD HE...
# ...                                                 ...
# 4071        BUT THEY COULD NEVER HAVE TAUGHT HIM ARABIC
# 4072  HE DECIDED TO CONCENTRATE ON MORE PRACTICAL MA...
# 4073                THAT'S WHAT I'M NOT SUPPOSED TO SAY
# 4074            JUST HANDLING THEM MADE HIM FEEL BETTER
# 4075                           THE CITY SEALER'S OFFICE
#
#                                                pred_str  \
# 0     BE CAREFUL WITH YOUR PROPMASTIGATIONS SAID THE...
# 1     THEN WHY SHOULD THEY BE SURPRISED WHEN THI SEE...
# 2     A YOUNG ARAB ALSO LOADED DOWN WITH BAGGAGE ENT...
# 3     I FELT THAT EVERYTHING I OWNED WOULD BE DESTROYED
# 4     HE MOVED ABOUT INVISIBLE BUT EVERY ONE COULD H...
# ...                                                 ...
# 4071        BUT THEY COULD NEVER HAVE TAUGHT HIM ARABIC
# 4072  HE DECIDED TO CONCENTRATE ON MORE PRACTICAL MA...
# 4073                THAT'S WHAT I'M NOT SUPPOSED TO SAY
# 4074                JUST ANDILY PO BAD HIM FEEL PICTURE
# 4075                           THE CITY SEALER'S OFFICE
#
#                                      pred_str_lowercase  similarity
# 0     be careful with your propmastigations said the...           1
# 1     then why should they be surprised when thi see...           0
# 2     a young arab also loaded down with baggage ent...           0
# 3     i felt that everything i owned would be destroyed           1
# 4     he moved about invisible but every one could h...           0
# ...                                                 ...         ...
# 4071        but they could never have taught him arabic           0
# 4072  he decided to concentrate on more practical ma...           0
# 4073                that's what i'm not supposed to say           0
# 4074                just andily po bad him feel picture           0
# 4075                           the city sealer's office           0
#
# [4076 rows x 6 columns]

# %%
# sanity check
results_df[results_df['similarity'] == 1]
# Out:
#       Unnamed: 0                        filename  \
# 0              0  cv-valid-dev/sample-000000.mp3
# 3              3  cv-valid-dev/sample-000003.mp3
# 55            55  cv-valid-dev/sample-000055.mp3
# 89            89  cv-valid-dev/sample-000089.mp3
# 159          159  cv-valid-dev/sample-000159.mp3
# ...          ...                             ...
# 3535        3535  cv-valid-dev/sample-003535.mp3
# 3553        3553  cv-valid-dev/sample-003553.mp3
# 3808        3808  cv-valid-dev/sample-003808.mp3
# 3817        3817  cv-valid-dev/sample-003817.mp3
# 3861        3861  cv-valid-dev/sample-003861.mp3
#
#                                                    text  \
# 0     BE CAREFUL WITH YOUR PROGNOSTICATIONS SAID THE...
# 3     I THOUGHT THAT EVERYTHING I OWNED WOULD BE DES...
# 55                              NO ONE ATTACKS AN OASIS
# 89        THE STRANGER SEEMED SATISFIED WITH THE ANSWER
# 159   THE FIRST RULE OF DON'T FIGHT CLUB IS LET'S TA...
# ...                                                 ...
# 3535  YOU SHOULD SEE THE OTHER GUY SPECIFICALLY HOW ...
# 3553   HE ASKED IT PLEASE NEVER TO STOP SPEAKING TO HIM
# 3808       I HAD TO TEST YOUR COURAGE THE STRANGER SAID
# 3817  TWO WOMEN WERE STILL MISSING WHEN THE FIREFIGH...
# 3861                    AND THEY ATTACKED AN EMPTY TENT
#
#                                                pred_str  \
# 0     BE CAREFUL WITH YOUR PROPMASTIGATIONS SAID THE...
# 3     I FELT THAT EVERYTHING I OWNED WOULD BE DESTROYED
# 55                              NO ONE ATTACKS AN OASIS
# 89         THE STRANGER SEEMED SATISFIED WIT THE ANSWER
# 159   THE FIRST RULE OF DON'T FIGHT CLUB IS LET'S TA...
# ...                                                 ...
# 3535  YOU SHOULD SEE THE OTHER GAY SPECIFICALLY HOW ...
# 3553   HE ASKED IT PLEASE NEVER TO STOP SPEAKING TO HIM
# 3808       I HAD TO TEST YOUR COURAGE THE STRANGER SAID
# 3817  TWO WOMEN WERE STILL MISSING WHEN THE FIRE FIG...
# 3861                      AND THEY ATTACKED AN INKY TAN
#
#                                      pred_str_lowercase  similarity
# 0     be careful with your propmastigations said the...           1
# 3     i felt that everything i owned would be destroyed           1
# 55                              no one attacks an oasis           1
# 89         the stranger seemed satisfied wit the answer           1
# 159   the first rule of don't fight club is let's ta...           1
# ...                                                 ...         ...
# 3535  you should see the other gay specifically how ...           1
# 3553   he asked it please never to stop speaking to him           1
# 3808       i had to test your courage the stranger said           1
# 3817  two women were still missing when the fire fig...           1
# 3861                      and they attacked an inky tan           1
#
# [65 rows x 6 columns]

# %%
# Get filenames of rows with hotwords
detected_files = results_df[results_df['similarity'] == 1]['filename'] 
detected_files
# Out:
# 0       cv-valid-dev/sample-000000.mp3
# 3       cv-valid-dev/sample-000003.mp3
# 55      cv-valid-dev/sample-000055.mp3
# 89      cv-valid-dev/sample-000089.mp3
# 159     cv-valid-dev/sample-000159.mp3
#                      ...
# 3535    cv-valid-dev/sample-003535.mp3
# 3553    cv-valid-dev/sample-003553.mp3
# 3808    cv-valid-dev/sample-003808.mp3
# 3817    cv-valid-dev/sample-003817.mp3
# 3861    cv-valid-dev/sample-003861.mp3
# Name: filename, Length: 65, dtype: object

# %%
# Save filenames to detected.txt
with open("similar-hotwords.txt", "w") as f:
    for filename in detected_files:
        f.write(f"{filename}\n")
